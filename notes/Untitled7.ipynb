# %%
# !chcp 65001

# !modal run d:\projects\smol-ai-developer\main.py --prompt "a Chrome extension that, when clicked, opens a small window with a page where you can enter a prompt for reading the currently open page and generating some response from openai"
# Out:
# Active code page: 65001
# 89 tokens in prompt: You are an AI developer who is trying to write a p
# 34 tokens in prompt: a Chrome extension that, when clicked, opens a sma
# hi its me, the smol developer! you said you wanted:
# a Chrome extension that, when clicked, opens a small window with a page where you can enter a prompt for reading the currently open page and generating some response from openai
# 145 tokens in prompt: You are an AI developer who is trying to write a p
# ['manifest.json', 'popup.html', 'popup.js']
# 34 tokens in prompt: a Chrome extension that, when clicked, opens a sma
# 202 tokens in prompt: You are an AI developer who is trying to write a p
# The files we have decided to generate are:
# - manifest.json
# - background.js
# - popup.html
# - popup.js
#
# The shared dependencies between these files are:
# - chrome
# - openai
# - DOM elements: "prompt-input", "response-output"
# - message names: "generate-response"
# shared_dependencies.md
# ...
